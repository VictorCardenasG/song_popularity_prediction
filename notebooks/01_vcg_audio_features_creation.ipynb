# %%
import pandas as pd
import requests
import base64
import time
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry

# %%
# Spotify API credentials
client_id = 'your_client_id'
client_secret = 'your_client_secret'

# Encode credentials
credentials = f"{client_id}:{client_secret}"
encoded_credentials = base64.b64encode(credentials.encode()).decode()

# Function to get Spotify access token
def get_access_token():
    auth_url = "https://accounts.spotify.com/api/token"
    headers = {
        "Authorization": f"Basic {encoded_credentials}"
    }
    data = {
        "grant_type": "client_credentials"
    }
    response = requests.post(auth_url, headers=headers, data=data)
    response_data = response.json()
    return response_data['access_token']

# Function to search for a track and get the track ID
def get_track_id(track_name, artist_name, access_token):
    search_url = "https://api.spotify.com/v1/search"
    headers = {
        "Authorization": f"Bearer {access_token}"
    }
    params = {
        "q": f"track:{track_name} artist:{artist_name}",
        "type": "track",
        "limit": 1
    }
    response = requests.get(search_url, headers=headers, params=params)
    response_data = response.json()
    tracks = response_data.get('tracks', {}).get('items', [])
    if tracks:
        return tracks[0]['id']
    return None

# Function to get audio features for a track
def get_audio_features(track_id, access_token):
    features_url = f"https://api.spotify.com/v1/audio-features/{track_id}"
    headers = {
        "Authorization": f"Bearer {access_token}"
    }
    response = requests.get(features_url, headers=headers)
    return response.json()

# Set up a requests session with retry logic
session = requests.Session()
retries = Retry(total=5, backoff_factor=1, status_forcelist=[429, 500, 502, 503, 504])
session.mount('https://', HTTPAdapter(max_retries=retries))

# Load the dataset
file_path = '../Most Streamed Spotify Songs 2024.csv'
data = pd.read_csv(file_path, encoding='ISO-8859-1')

# Ensure all values in 'Track' and 'Artist' columns are strings
data['Track'] = data['Track'].astype(str)
data['Artist'] = data['Artist'].fillna('Unknown Artist').astype(str)

# Extract track names and artist names
tracks = data[['Track', 'Artist']]

# Get Spotify access token
access_token = get_access_token()

# Create lists to store audio features and tracks not found
audio_features_list = []
not_found_tracks = []

# Function to save progress
def save_progress(audio_features_list, not_found_tracks):
    audio_features_df = pd.DataFrame(audio_features_list)
    audio_features_df.to_csv('audio_features.csv', index=False)
    not_found_tracks_df = pd.DataFrame(not_found_tracks, columns=['Track', 'Artist'])
    not_found_tracks_df.to_csv('not_found_tracks.csv', index=False)

# Iterate over each track to get audio features
for index, row in tracks.iterrows():
    track_name = row['Track']
    artist_name = row['Artist']
    
    # Handle encoding issues
    track_name = track_name.encode('utf-8', 'ignore').decode('utf-8')
    artist_name = artist_name.encode('utf-8', 'ignore').decode('utf-8')
    
    try:
        track_id = get_track_id(track_name, artist_name, access_token)
        if track_id:
            audio_features = get_audio_features(track_id, access_token)
            audio_features['Track'] = track_name
            audio_features['Artist'] = artist_name
            audio_features_list.append(audio_features)
            print(f"Found and added: {track_name} by {artist_name}")
        else:
            not_found_tracks.append((track_name, artist_name))
            print(f"Track ID not found for {track_name} by {artist_name}")
        time.sleep(0.5)  # Sleep to avoid hitting rate limits
    except requests.exceptions.RequestException as e:
        print(f"Error retrieving data for {track_name} by {artist_name}: {e}")
        not_found_tracks.append((track_name, artist_name))
    
    # Periodically save progress every 10 iterations
    if (index + 1) % 10 == 0:
        save_progress(audio_features_list, not_found_tracks)

# Final save at the end
save_progress(audio_features_list, not_found_tracks)

# Print summary
print(f"\nTotal tracks processed: {len(tracks)}")
print(f"Tracks found and added: {len(audio_features_list)}")
print(f"Tracks not found: {len(not_found_tracks)}")

print("Audio features have been saved to audio_features.csv")
print("Tracks not found have been saved to not_found_tracks.csv")
# Out:
# Found and added: MILLION DOLLAR BABY by Tommy Richman
# Found and added: Not Like Us by Kendrick Lamar
# Found and added: i like the way you kiss me by Artemas
# Found and added: Flowers by Miley Cyrus
# Found and added: Houdini by Eminem
# Found and added: Lovin On Me by Jack Harlow
# Found and added: Beautiful Things by Benson Boone
# Found and added: Gata Only by FloyyMenor
# Found and added: Danza Kuduro - Cover by MUSIC LAB JPN
# Found and added: BAND4BAND (feat. Lil Baby) by Central Cee
# Found and added: I Had Some Help (feat. Morgan Wallen) by Post Malone
# Found and added: The Door by Teddy Swims
# Found and added: LUNCH by Billie Eilish
# Found and added: Like That by Future
# Found and added: bathroom floor by Kids With Buns
# Found and added: LALA by Myke Towers
# Found and added: Fortnight (feat. Post Malone) by Taylor Swift
# Found and added: greedy by Tate McRae
# Found and added: BLUE by Billie Eilish
# Found and added: As It Was by Harry Styles
# Found and added: Paint The Town Red by Doja Cat
# Found and added: Espresso by Sabrina Carpenter
# Found and added: Danza Kuduro - Cover by MUSIC LAB JPN
# Track ID not found for TEXAS HOLD 'EM by Beyoncï¿
# Track ID not found for Future by official sound studio
# Found and added: Beat Automotivo Tan Tan Tan Viral by WZ Beat
# Found and added: STAY (with Justin Bieber) by The Kid LAROI
# Found and added: Baby Shark by Pinkfong
# Found and added: we can't be friends (wait for your love) by Ariana Grande
# Found and added: Numb / Encore by JAY-Z
# Found and added: Danza Kuduro - Cover by LOVE BGM JPN
# Found and added: SHEESH by BABYMONSTER
# Found and added: Water by Tyla
# Found and added: Strangers by Kenya Grace
# Found and added: Too Sweet by Hozier
# Found and added: What's Love Got to Do with It - 2023 Remaster by Tina Turner
# Found and added: A Bar Song (Tipsy) by Shaboozey
# Found and added: Lose Control by Teddy Swims
# Found and added: fukumean by Gunna
# Found and added: Dance Monkey by Tones And I
# Found and added: BIRDS OF A FEATHER by Billie Eilish
# Track ID not found for Cupid ï¿½ï¿½ï¿½ Twin Ver. (FIFTY FIFTY) ï¿½ï¿½ï¿½ Spe by sped up 8282
# Found and added: I'm Good (Blue) by David Guetta
# Found and added: Daylight by David Kushner
# Found and added: My Love Mine All Mine by Mitski
# Found and added: Please Please Please by Sabrina Carpenter
# Found and added: Houdini by Dua Lipa
# Found and added: Danza Kuduro - Cover by MUSIC LAB JPN
# Found and added: If We Ever Broke Up by Mae Stephens
# Found and added: Despacito by Luis Fonsi
# Found and added: euphoria by Kendrick Lamar
# Found and added: Panda Basi by Mvua
# Found and added: Calm Down (with Selena Gomez) by Rema
# Found and added: Shape of You by Ed Sheeran
# Found and added: Mitu by Maian
# Found and added: Blinding Lights by The Weeknd
# Found and added: Creepin' (with The Weeknd & 21 Savage) by Metro Boomin
# Found and added: Dona Felicidade by Patati Patatï¿
# Found and added: Danza Kuduro - Cover by MUSIC LAB JPN
# Found and added: Unholy (feat. Kim Petras) by Sam Smith
# Found and added: Stereo Love - Melodic by Edward Maya
# Track ID not found for Very Cute Melody by Marimba Tone (39813) by mitsu sound
# Found and added: Supernova by aespa
# Found and added: Me Porto Bonito by Bad Bunny
# Found and added: Back That Azz Up (feat. Lil Wayne & Mannie Fresh) by JUVENILE
# Found and added: Calm Down by Rema
# Found and added: CARNIVAL by ýý$
# Found and added: Kill Bill by SZA
# Found and added: What Was I Made For? [From The Motion Picture "Barbie"] by Billie Eilish
# Found and added: Babba by Guy Mac
# Found and added: Heat Waves by Glass Animals
# Found and added: In the End by Linkin Park
# Found and added: Shakira: Bzrp Music Sessions, Vol. 53 by Bizarrap
# Found and added: The Way We Move - Extended Mix by PowerDress
# Found and added: Old Town Road by Lil Nas X
# Found and added: un x100to by Grupo Frontera
# Track ID not found for Laxed ï¿½ï¿½ï¿½ Sire by Jawsh 685
# Found and added: Sprinter by Dave
# Found and added: CHIHIRO by Billie Eilish
# Found and added: TQG by KAROL G
# Found and added: Perfect by Ed Sheeran
# Found and added: Pepas by Farruko
# Found and added: Peekaboo by Dave Angel
# Found and added: Ella Baila Sola by Eslabon Armado
# Found and added: Dance The Night - From Barbie The Album by Dua Lipa
# Found and added: La Bebe - Remix by Yng Lvcas
# Found and added: redrum by 21 Savage
# Found and added: Easy On Me by Adele
# Track ID not found for Titï¿½ï¿½ Me Pregu by Bad Bunny
# Found and added: All My Life (feat. J. Cole) by Lil Durk
# Found and added: Anti-Hero by Taylor Swift
# Found and added: Quevedo: Bzrp Music Sessions, Vol. 52 by Bizarrap
# Found and added: Magnetic by ILLIT
# Found and added: Lollipop by Darell
# Found and added: La Diabla by Xavi
# Track ID not found for Boy's a Liar Pt. 2 by PinkPantheress
# Found and added: Snooze by SZA
# Found and added: BELLAKEO by Peso Pluma
# Found and added: Agora Hills by Doja Cat
# Found and added: Prada by cassï¿
# Found and added: Montagem Rave Eterno by Dj Samir
# Found and added: Lil Boo Thang by Paul Russell
# Found and added: MONACO by Bad Bunny
# Found and added: Laxed (Siren Beat) by Jawsh 685
# Found and added: (It Goes Like) Nanana - Edit by Peggy Gou
# Found and added: Training Season by Dua Lipa
# Found and added: Type Shit by Future
# Found and added: Armageddon by aespa
# Found and added: The Box by Roddy Ricch
# Found and added: INDUSTRY BABY (feat. Jack Harlow) by Lil Nas X
# Found and added: Pedro by Jaxomy
# Found and added: Fast Car by Luke Combs
# Found and added: Bling-Bang-Bang-Born by Creepy Nuts
# Found and added: Aesthetic by Tollan Kim
# Found and added: Sunflower - Spider-Man: Into the Spider-Verse by Post Malone
# Track ID not found for Hands by Dianï¿½
# Found and added: Saturn by SZA
# Found and added: Chegou a Hora de Ir para Cama (Playback) by 3 Palavrinhas
# Found and added: Believer by Imagine Dragons
# Found and added: WAIT FOR U (feat. Drake & Tems) by Future
# Found and added: I KNOW ? by Travis Scott
# Found and added: ANDO by Jere Klein
# Found and added: First Class by Jack Harlow
# Found and added: FE!N by Travis Scott
# Found and added: Save Your Tears - Live by The Weeknd
# Found and added: Losing Interest - Original Mix by Goovex
# Found and added: I Ain't Worried by OneRepublic
# Track ID not found for MI EX TENï¿½ï¿½A RA by KAROL G
# Found and added: Drained of Color by Exhumed
# Found and added: Mood (feat. iann dior) by 24kGoldn
# Found and added: Dynamite by BTS
# Found and added: Looking Like a Wow End of Year 2023 by WasteLand
# Found and added: BIG BANK (feat. 2 Chainz, Big Sean, Nicki Minaj) by YG
# Track ID not found for Bï¿½ï¿½ï¿½n ï¿½ï¿½ï¿½ï¿½ï¿½ by Karik
# Track ID not found for Drifting by Tiï¿½ï¿
# Found and added: Over the Rainbow by Israel Kamakawiwo'ole
# Found and added: Losin Control by Russ
# Found and added: Onana by Jey One
# Found and added: Daechwita by Agust D
# Found and added: Como Si No Importara by Emilia
# Found and added: Supernova by SAIKO
# Found and added: Rags2Riches (feat. ATR Son Son) by Rod Wave
# Found and added: Fast Car by Jonas Blue
# Found and added: Quickie by Moneybagg Yo
# Track ID not found for Coraï¿½ï¿½ï¿½ï¿½o by Marï¿½ï¿½lia Mendo
# Track ID not found for Vultures by ýý$
# Track ID not found for MY HOUSE by Beyoncï¿
# Found and added: The Thin Grey Line by $uicideboy$
# Track ID not found for Alo by corwinn
# Found and added: Fear Of Heights by Drake
# Found and added: Desde Mis Ojos - Remix by Chris Lebron
# Found and added: Prayer in C - Robin Schulz Radio Edit by Lilly Wood and The Prick
# Found and added: Bam Lagatar by Khushi Kakkar
# Found and added: Who Is Your Guy? - Remix by Spyro
# Found and added: Rover by KAI
# Found and added: From The Start by Laufey
# Found and added: Slimed In by Future
# Found and added: Gentleman by PSY
# Found and added: SUGAR by BROCKHAMPTON
# Found and added: Everybody Talks by Neon Trees
# Found and added: OKLOSER by Doja Cat
# Found and added: Pump It Up by Endor
# Found and added: Standing Room Only by Tim McGraw
# Track ID not found for ýýýýýý by WINE
# Found and added: Back To Back (feat. Future) by Nardo Wick
# Found and added: Shotta Flow by NLE Choppa
# Found and added: Baddest by Yung Bleu
# Found and added: Cigarettes by Juice WRLD
# Found and added: bad by wave to earth
# Found and added: ISABELLE by Sefo
# Found and added: Cure For Me by AURORA
# Track ID not found for Tï¿½ï¿½ï¿½n by Wren Evans
# Found and added: Pistoleta by Olexesh
# Found and added: LOYALTY. FEAT. RIHANNA. by Kendrick Lamar
# Found and added: Deep in the Water by Don Toliver
# Found and added: Endless Fashion (feat. Nicki Minaj) by Lil Uzi Vert
# Found and added: A Mimir En El Chat by Dejavu FF
# Found and added: Temporary pyar by Kaka
# Found and added: AA by Walker Hayes
# Found and added: Phir Bhi Tumko Chaahunga by Mithoon
# Found and added: Passinho Debochado by Dan Ventura
# Found and added: Go Hard by Lil Baby
# Found and added: La La La (Brazil 2014) by Shakira
# Track ID not found for i'm yours sped up by Isabel LaRosa
# Found and added: Ruaan (From "Tiger 3") by Pritam
# Found and added: Summer of Love (Shawn Mendes & Tainy) by Shawn Mendes
# Found and added: God of Music by SEVENTEEN
# Track ID not found for ýýýH+3+ýýýýýýý7luCJIo0T6... by vyrval
# Found and added: Embarrassed (feat. Travis Scott) by Don Toliver
# Found and added: Carrying Your Love by David Morris
# Found and added: Dueles by Jesse & Joy
# Found and added: Tipo Hollywood by Mc Ws da leste
# Track ID not found for Oye by LuckReaper
# Found and added: She Don't Give a Fo by Duki
# Found and added: 085 - Ao Vivo by MC Rogerinho
# Found and added: MODELITO by Mora
# Track ID not found for Los animales en el autobï¿½ by Luli Pampï¿½
# Found and added: Super Bass by Nicki Minaj
# Track ID not found for Ex's & Oh's by Elle King
# Found and added: Boys by Charli xcx
# Found and added: Chorei na Vaquejada by Eric Land
# Found and added: Zarzour by Lartiste
# Found and added: Ella by Junior H
# Found and added: REPEAT IT by Lil Tecca
# Found and added: Teri Aankhon Mein by Darshan Raval
# Found and added: Animals by Martin Garrix
# Found and added: Way Back Home by SHAUN
# Found and added: NDA by Billie Eilish
# Found and added: Casper by Takeoff
# Track ID not found for DANï¿½ï¿½A by PEDRO SAMPAIO
# Found and added: Cry Baby (feat. DaBaby) by Megan Thee Stallion
# Found and added: Cumbia Buena by Grupo la Cumbia
# Found and added: Happy Birthday by YolyBoy
# Found and added: 8 Raflaan (feat. Gurlez Akhtar) by Mankirt Aulakh
# Found and added: DFMU by Ella Mai
# Found and added: Slippery (feat. Gucci Mane) by Migos
# Found and added: Woo Baby (feat. Chris Brown) by Pop Smoke
# Found and added: Haegeum by Agust D
# Found and added: Sisa Rasa by Mahalini
# Track ID not found for Mockingbird by Tiï¿½ï¿
# Track ID not found for Don't Rush (feat. Headie One) by Young T & Bugsey
# Found and added: The Heart Part 5 by Kendrick Lamar
# Found and added: A Ella by KAROL G
# Found and added: Nachts wach by Miksu / Macloud
# Found and added: Superpowers by Daniel Caesar
# Track ID not found for Who's Laughing Now by Ava Max
# Found and added: Smells Like Teen Spirit by Nirvana
# Found and added: 2 Million Up by Peezy
# Found and added: In the morning by ITZY
# Found and added: Such a Whore (Stellular Remix) by JVLA
# Track ID not found for ýýýýýýýýýýýý by Lamis Kan
# Track ID not found for quï¿½ï¿½ le pasa conm by Nicki Nicole
# Found and added: Medusa by Jhay Cortez
# Found and added: SEJODIOTO by KAROL G
# Found and added: Luminary by Joel Sunny
# Found and added: Welcome To The Party by Pop Smoke
# Found and added: All Night Longer by seyhqnsert
# Found and added: ARRANCARMELO by WOS
# Found and added: Mast Malang Jhoom (From "Bade Miyan Chote Miyan - Kannada") by Vishal Mishra
# Found and added: Uno by Ambjaay
# Found and added: Country Girl (Shake It For Me) by Luke Bryan
# Found and added: Dawai (From "Air Mata Di Ujung Sajadah") by Fadhilah Intan
# Found and added: The Greatest Show by Hugh Jackman
# Found and added: Cake By The Ocean - Cover by MUSIC LAB JPN
# Track ID not found for ýýýýýýýýýýýý (White Flag) by NONT TANONT
# Found and added: Hood By Air Freestyle by Baby Flaco
# Found and added: Stupid Love by Lady Gaga
# Found and added: ACHO PR by Bad Bunny
# Found and added: ATM by Nemzzz
# Found and added: Di Que Si by Grupo Marca Registrada
# Found and added: Doin' Time by Lana Del Rey
# Found and added: Come & Get It by Selena Gomez
# Track ID not found for Por Fin Te Encontrï¿ by Cali Y El Dandee
# Found and added: I.F.L.Y. by Bazzi
# Found and added: Crazy Story by King Von
# Found and added: CARNAL by Peso Pluma
# Found and added: AirBnb by ian
# Found and added: LOS PITS by Bad Bunny
# Found and added: Queen of Mean by Sarah Jeffery
# Found and added: Minefields by Faouzia
# Found and added: my future by Billie Eilish
# Found and added: The Way I Are by Timbaland
# Found and added: God is a woman by Ariana Grande
# Found and added: SNAP - High and Fast by Rosa Linn
# Track ID not found for Supera by Marï¿½ï¿½lia Mendo
# Found and added: Tu Juliet Jatt Di ( From "Jatt & Juliet 3") by Diljit Dosanjh
# Found and added: When I Grow Up by NF
# Found and added: Pa Mi by Dalex
# Found and added: Tera Fitoor by Arijit Singh
# Track ID not found for B.S. (feat. H.E.R.) by Jhenï¿½ï¿½
# Found and added: Traicionera by Sebastian Yatra
# Found and added: Already Dead by Juice WRLD
# Found and added: Kokomo by The Beach Boys
# Found and added: Cham Cham by Meet Bros.
# Found and added: You by Willy Paul
# Track ID not found for What's Love Got to Do with It by Kygo
# Found and added: TV Shapes by Bubbatrees
# Found and added: Delilah (pull me out of this) by Fred again..
# Found and added: Outside Today by YoungBoy Never Broke Again
# Track ID not found for Don't You Worry Child - Radio Edit by Swedish House Mafia
# Found and added: Focus by Ariana Grande
# Found and added: Fuentes de Ortiz by Ed Maverick
# Found and added: Freezing by purpl
# Found and added: NASTY by Russ
# Track ID not found for Mama's Boy by Dominic Fike
# Found and added: Welcome To Brixton by SR
# Found and added: DArkSide by Bring Me The Horizon
# Found and added: MEMORIES! by 347aidan
# Found and added: Morado by J Balvin
# Found and added: The Hillbillies by Baby Keem
# Track ID not found for Bodak Yellow by Serranow
# Found and added: Asesina - Remix by Brytiago
# Found and added: Braten by Steps
# Track ID not found for Dayanamï¿½ï¿½y by Kerim Araz
# Found and added: Daylight by Harry Styles
# Found and added: Happiest Year by Jaymes Young
# Track ID not found for 3 Haselnï¿½ï¿ by Jaques Raupï¿
# Track ID not found for Jaragandi (From "Game Changer") (Telugu) by Thaman S
# Track ID not found for ýýýýýýýýýýýý (ýýýýýýýýýýýýýý ýýýýýýýýýýýý) [prod. by wex & heysubr] by BUSHIDO ZHO
# Found and added: For the Last Time by $uicideboy$
# Found and added: Dil Meri Na Sune by Atif Aslam
# Found and added: Grace (feat. 42 Dugg) by Lil Baby
# Found and added: Nashe Si Chadh Gayi by Arijit Singh
# Track ID not found for Me Acostumbre (feat. Bad Bunny) by Arcï¿½ï¿½
#
# Total tracks processed: 4600
# Tracks found and added: 1730
# Tracks not found: 2870
# Audio features have been saved to audio_features.csv
# Tracks not found have been saved to not_found_tracks.csv

# %%
# Load dataset
file_path = 'C:/Users/Victor Cardenas/Documents/dataset_projects/spotify_streaming/audio_features.csv'
audio_features = pd.read_csv(file_path, encoding='latin1')

# Display the first few rows of the dataframe
audio_features
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.852   0.697    1    -5.520     0       0.0439      0.097300
# 1            0.898   0.472    1    -7.001     1       0.0776      0.010700
# 2            0.599   0.946   11    -4.263     1       0.0447      0.000938
# 3            0.706   0.691    0    -4.775     1       0.0633      0.058400
# 4            0.936   0.887    9    -2.760     0       0.0683      0.029200
# ...            ...     ...  ...       ...   ...          ...           ...
# 1725         0.502   0.168    1   -14.061     1       0.0486      0.885000
# 1726         0.844   0.533    1    -9.612     1       0.5520      0.073500
# 1727         0.574   0.729    9    -4.200     1       0.0473      0.349000
# 1728         0.824   0.513   10    -6.263     0       0.3600      0.384000
# 1729         0.800   0.779    4    -5.515     0       0.0553      0.113000
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000370    0.0678    0.919  138.029  audio_features
# 1             0.000000    0.1410    0.214  101.061  audio_features
# 2             0.010600    0.0826    0.747  151.647  audio_features
# 3             0.000070    0.0232    0.632  118.048  audio_features
# 4             0.000002    0.0582    0.889  127.003  audio_features
# ...                ...       ...      ...      ...             ...
# 1725          0.000000    0.1110    0.355  112.881  audio_features
# 1726          0.000003    0.0953    0.230  140.078  audio_features
# 1727          0.000002    0.6640    0.470  163.748  audio_features
# 1728          0.000000    0.1090    0.179  123.023  audio_features
# 1729          0.000000    0.2060    0.266   96.948  audio_features
#
#                           id                                   uri  \
# 0     5AJ9hqTS2wcFQCELCFRO7A  spotify:track:5AJ9hqTS2wcFQCELCFRO7A
# 1     6AI3ezQ4o3HUoP6Dhudph3  spotify:track:6AI3ezQ4o3HUoP6Dhudph3
# 2     2GxrNKugF82CnoRFbQfzPf  spotify:track:2GxrNKugF82CnoRFbQfzPf
# 3     7DSAEUvxU8FajXtRloy8M0  spotify:track:7DSAEUvxU8FajXtRloy8M0
# 4     2HYFX63wP3otVIvopRS99Z  spotify:track:2HYFX63wP3otVIvopRS99Z
# ...                      ...                                   ...
# 1725  219slQu3ALbTSAe9P22hvE  spotify:track:219slQu3ALbTSAe9P22hvE
# 1726  240audWazVjwvwh7XwfSZE  spotify:track:240audWazVjwvwh7XwfSZE
# 1727  4ILc7H2NfGbzbrHBclNOtB  spotify:track:4ILc7H2NfGbzbrHBclNOtB
# 1728  01JMnRUs2YOK6DDpdQASGY  spotify:track:01JMnRUs2YOK6DDpdQASGY
# 1729  2EKXTA9QxkW6XeQ2uEeIii  spotify:track:2EKXTA9QxkW6XeQ2uEeIii
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/5AJ9hqTS2wcF...
# 1     https://api.spotify.com/v1/tracks/6AI3ezQ4o3HU...
# 2     https://api.spotify.com/v1/tracks/2GxrNKugF82C...
# 3     https://api.spotify.com/v1/tracks/7DSAEUvxU8Fa...
# 4     https://api.spotify.com/v1/tracks/2HYFX63wP3ot...
# ...                                                 ...
# 1725  https://api.spotify.com/v1/tracks/219slQu3ALbT...
# 1726  https://api.spotify.com/v1/tracks/240audWazVjw...
# 1727  https://api.spotify.com/v1/tracks/4ILc7H2NfGbz...
# 1728  https://api.spotify.com/v1/tracks/01JMnRUs2YOK...
# 1729  https://api.spotify.com/v1/tracks/2EKXTA9QxkW6...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/5AJ9...       155152
# 1     https://api.spotify.com/v1/audio-analysis/6AI3...       274192
# 2     https://api.spotify.com/v1/audio-analysis/2Gxr...       142515
# 3     https://api.spotify.com/v1/audio-analysis/7DSA...       200600
# 4     https://api.spotify.com/v1/audio-analysis/2HYF...       227239
# ...                                                 ...          ...
# 1725  https://api.spotify.com/v1/audio-analysis/219s...       228443
# 1726  https://api.spotify.com/v1/audio-analysis/240a...       156081
# 1727  https://api.spotify.com/v1/audio-analysis/4ILc...       236000
# 1728  https://api.spotify.com/v1/audio-analysis/01JM...       203438
# 1729  https://api.spotify.com/v1/audio-analysis/2EKX...       238289
#
#       time_signature                       Track          Artist
# 0                  4         MILLION DOLLAR BABY   Tommy Richman
# 1                  4                 Not Like Us  Kendrick Lamar
# 2                  4  i like the way you kiss me         Artemas
# 3                  4                     Flowers     Miley Cyrus
# 4                  4                     Houdini          Eminem
# ...              ...                         ...             ...
# 1725               3               Happiest Year    Jaymes Young
# 1726               4           For the Last Time     $uicideboy$
# 1727               4            Dil Meri Na Sune      Atif Aslam
# 1728               4       Grace (feat. 42 Dugg)        Lil Baby
# 1729               4         Nashe Si Chadh Gayi    Arijit Singh
#
# [1730 rows x 20 columns]

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# Spotify API credentials
client_id = 'your_client_id'
client_secret = 'your_client_secret'

# Authenticate with the Spotify API
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=client_id, client_secret=client_secret))

# Replace this with your playlist ID (without query parameters)
playlist_id = '2OPncXZPbD73X3WbRCEk7x'

# Get the tracks from the playlist
results = sp.playlist_tracks(playlist_id)
tracks = results['items']

# Get more tracks if the playlist has more than 100 tracks
while results['next']:
    results = sp.next(results)
    tracks.extend(results['items'])

# Extract track IDs
track_ids = [track['track']['id'] for track in tracks]

# Get audio features
audio_features = sp.audio_features(track_ids)

# Create a DataFrame
df = pd.DataFrame(audio_features, columns=['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
                                           'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
                                           'duration_ms'])

# Save to CSV (optional)
df.to_csv('spotify_playlist_audio_features.csv', index=False)

df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.708   0.737    1    -4.045     1       0.0436        0.0739
# 1         0.706   0.691    0    -4.775     1       0.0633        0.0584
# 2         0.687   0.606    7    -5.920     1       0.0262        0.1780
# 3         0.578   0.654    1   -12.421     0       0.0562        0.1210
# 4         0.621   0.782    2    -5.548     1       0.0440        0.0125
#
#    instrumentalness  liveness  valence    tempo  duration_ms
# 0          0.001620    0.0955    0.607   91.986       197920
# 1          0.000070    0.0232    0.632  118.048       200600
# 2          0.000326    0.0830    0.748   80.569       206307
# 3          0.000004    0.0673    0.621  129.513       216467
# 4          0.033000    0.2300    0.550  128.033       198938

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# Spotify API credentials
client_id = 'your_client_id'
client_secret = 'your_client_secret'

# Authenticate with the Spotify API
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=client_id, client_secret=client_secret))

# Replace this with your playlist ID (without query parameters)
playlist_id = '1zRN5JeaS7EE6JcIiUqAUh'

# Get the tracks from the playlist
results = sp.playlist_tracks(playlist_id)
tracks = results['items']

# Get more tracks if the playlist has more than 100 tracks
while results['next']:
    results = sp.next(results)
    tracks.extend(results['items'])

# Extract track IDs, names, and artist names
track_ids = [track['track']['id'] for track in tracks]
track_names = [track['track']['name'] for track in tracks]
artist_names = [', '.join([artist['name'] for artist in track['track']['artists']]) for track in tracks]

# Get audio features
audio_features = sp.audio_features(track_ids)

# Add track names and artist names to audio features
for i, feature in enumerate(audio_features):
    feature['track'] = track_names[i]
    feature['artist'] = artist_names[i]

# Create a DataFrame
df = pd.DataFrame(audio_features, columns=['track', 'artist', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
                                           'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
                                           'duration_ms'])

# Save to CSV (optional)
df.to_csv('spotify_random_playlist.csv', index=False)

df.head()
# Out:
#                         track          artist  danceability  energy  key  \
# 0                    The Show   Kerris Dorsey         0.594  0.0658    9
# 1  A Little Bit of Everything           Dawes         0.572  0.1620    5
# 2             The Lady In Red  Chris de Burgh         0.548  0.2940   10
# 3         Baby Can I Hold You   Tracy Chapman         0.692  0.4220    2
# 4        You're Somebody Else      flora cash         0.713  0.4520    1
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0   -16.422     0       0.0627        0.9510          0.000000    0.0823
# 1   -20.962     1       0.0409        0.4340          0.000000    0.2080
# 2   -17.112     1       0.0333        0.3320          0.000003    0.0392
# 3   -10.533     1       0.0333        0.0811          0.000000    0.0848
# 4    -9.638     1       0.0295        0.8410          0.003800    0.1050
#
#    valence    tempo  duration_ms
# 0    0.578  149.314       193787
# 1    0.262   73.099       342787
# 2    0.491   76.698       256173
# 3    0.468   74.375       193120
# 4    0.235  102.963       218883
